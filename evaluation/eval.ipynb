# %% [markdown]
# # Data Extraction

# %%
import re, pandas as pd
from glob import glob
from PyPDF2 import PdfReader
import time

# %%
def extract_workout_from_pdf(pdf_path):
    # tables = camelot.read_pdf(pdf_path, flavor='lattice', pages='1-end')
    # if not tables.n:
    #     tables = camelot.read_pdf(pdf_path, flavor='stream', pages='1-end')
    # df_tables = [t.df[0].str.split("\n", expand=True) for t in tables]

    reader = PdfReader(pdf_path)
    raw_text = reader.pages[0].extract_text()  

    data = {'pdf_path': pdf_path}

    tables_pattern = re.compile(
        r'(?s)\A(.+?)(?=\nMUSCLEANDSTRENGTH\.COM)',
    )
    m = tables_pattern.search(raw_text)
    tables = m.group(1).strip() if m else None
    data['tables'] = tables

    labels = (
        "Main Goal|Training Level|Program Duration|"
        "Days Per Week|Time Per Workout|Equipment|Author|Target Gender"
    )
    metadata_pattern = re.compile(
        rf"(?P<label>{labels}):\s*"
        r"(?P<value>[^:]+?)(?="
        rf"(?:{labels}):|$)"
    )
    for m in metadata_pattern.finditer(raw_text):
        label = m.group("label").strip()
        value = m.group("value").strip()
        data[label] = value


    desc_pattern = re.compile(
        r"""MUSCLEANDSTRENGTH\.COM[\s\S]*?Tools\s*\n 
        (?P<desc>[\s\S]+?)             
        (?=\nMain\s+Goal:)          
        """,
        re.VERBOSE | re.MULTILINE
    )

    m = desc_pattern.search(raw_text)
    if m:
        desc = m.group("desc").strip()
    else:
        desc_pattern = re.compile(
            r"MUSCLEANDSTRENGTH\.COM\s*\r?\n"
            r"(?P<desc>.*?)"
            r"(?=\r?\nMain\s+Goal:)",
            re.DOTALL
        )
        m = desc_pattern.search(raw_text)
        desc = m.group("desc").strip() if m else None
    data['Description'] = desc

    # data['raw_text'] = raw_text

    return pd.DataFrame.from_dict(data, orient='index').T

# %%
all_plans = []
for pdf in glob('./samples/**/*.pdf'):
    all_plans.append(extract_workout_from_pdf(pdf))

master_df = pd.concat(all_plans, ignore_index=True)
master_df.to_csv('workouts_data.csv', index=False)

# %%
master_df = pd.read_csv('workouts_data.csv')
master_df
# Out:
#                                              pdf_path  \
# 0                   ./samples/back/8weekchestback.pdf
# 1             ./samples/back/backandshoulderwomen.pdf
# 2                     ./samples/back/cobraworkout.pdf
# 3   ./samples/begineer/12weekfullbodyworkoutroutin...
# 4   ./samples/begineer/4dayupperlowerplantfitnessw...
# 5             ./samples/begineer/bodyweightbasics.pdf
# 6       ./samples/begineer/thebest15minutewarmups.pdf
# 7      ./samples/chest/12weekstoabiggerbenchpress.pdf
# 8                ./samples/chest/bestchestworkout.pdf
# 9   ./samples/chest/pecpounder8weekchestworkouttos...
# 10  ./samples/fat-loss/8weekbeginnerfatlossworkout...
# 11  ./samples/fat-loss/8weekbeginnerfatlossworkout...
# 12              ./samples/fat-loss/fatdestroyer_0.pdf
# 13                 ./samples/fat-loss/springshred.pdf
# 14  ./samples/full-body/2weekworkoutplantojumpstar...
# 15  ./samples/full-body/3dayfullbodyplantfitnesswo...
# 16  ./samples/full-body/thebestfullbodyworkoutrout...
# 17               ./samples/full-body/totalpackage.pdf
# 18  ./samples/home/15minutecoreconditioningworkout...
# 19  ./samples/home/3dayfullbodybeginnerkettlebellw...
# 20  ./samples/home/4dayathomeglutebuildingworkout.pdf
# 21                     ./samples/home/bandworkout.pdf
# 22                     ./samples/legs/bootyburner.pdf
# 23                     ./samples/legs/buttbuilder.pdf
# 24              ./samples/legs/rp-21glutebuilding.pdf
# 25  ./samples/legs/wheelsworkout8weekprogramtobuil...
# 26  ./samples/muscle-building/5daymuscleandstrengt...
# 27       ./samples/muscle-building/dumbbellonly_0.pdf
# 28  ./samples/muscle-building/dumbbellworkout5day_...
# 29      ./samples/muscle-building/upper_lower4day.pdf
# 30            ./samples/shoulder/coconutshoulders.pdf
# 31  ./samples/shoulder/deltoiddestructionhighvolum...
# 32  ./samples/shoulder/theperfectworkoutforrocksol...
# 33            ./samples/strength/3daypushpulllegs.pdf
# 34  ./samples/strength/advancedstrengthbuildingwor...
# 35         ./samples/strength/boostyourbenchpress.pdf
# 36  ./samples/strength/superstrength8weekstrengthb...
#
#                                                tables          Main Goal  \
# 0   Monday - Back & Chest\nExercise Sets Reps\nWor...       Build Muscle
# 1   Workout Routine for Women\nExercise Sets Reps\...       Build Muscle
# 2   Monday: Super Thick Workout\nExercise Sets Rep...       Build Muscle
# 3   Weeks 1-3: Total Body Circuit Workout\nDuring ...       Build Muscle
# 4   Planet Fitness Upper Body Workout A\nExercise ...       Build Muscle
# 5   Day 1: Upper Body\nExercise Sets Reps\nPull Up...    General Fitness
# 6   Exercise Sets Reps/Time Rest\nFast-Paced Walk ...    General Fitness
# 7   Monday\nExercise Sets Reps\nBench Press 3 See ...  Increase Strength
# 8   The Stretch & Push Workout\nExercise Sets Reps...       Build Muscle
# 9   The Hybrid PRRS™ Method\nExercise Tempo Sets R...       Build Muscle
# 10  Exercise Sets Reps Rest\nDumbbell Pullover 2 1...           Lose Fat
# 11  Exercise Sets Reps\nIncline Dumbbell Press 3 1...           Lose Fat
# 12  Day 1\nExercise Sets Reps\nUpper A\nIncline Be...       Build Muscle
# 13  Day 1: Chest & Abs\nExercise Warm Up Sets Work...           Lose Fat
# 14  Exercise Sets Reps Rest\nBarbell  or  Dumbbell...    General Fitness
# 15  Planet Fitness Full Body Workout Day 1\nExerci...       Build Muscle
# 16  Women's Full Body Workout 1\nExercise Sets Rep...           Lose Fat
# 17  Day 1\nExercise Sets Reps\nSquat 5 5\nDumbbell...       Build Muscle
# 18  Exercise Sets Reps Rest\nSit Up 2 - 3 15 None\...    General Fitness
# 19  Full Body Kettlebell Workout 1\nExercise Sets ...       Build Muscle
# 20  Exercise Sets Reps\nBent Over Dumbbell Row 2 -...       Build Muscle
# 21  Day 1: Push\nExercise Sets/Reps Tempo Rests\nS...       Build Muscle
# 22  The Booty Burner Workout\nExercise Sets Reps\n...       Build Muscle
# 23  The Butt Builder\nExercise Sets Reps\nSuperset...       Build Muscle
# 24  RP-21 Glute Workout\nExercise Sets Reps\nDynam...       Build Muscle
# 25  Leg Day 1: Hamstring Emphasis \nExercise Sets ...       Build Muscle
# 26  Monday: Upper Body Strength Workout\nExercise ...       Build Muscle
# 27  Day 1\nExercise Sets Reps\n1. Dumbbell Squat 3...       Build Muscle
# 28  Day 1: Chest, Shoulders & Triceps Dumbbell Wor...       Build Muscle
# 29  Day 1\nExercise Sets Reps\nUpper Body\nBench P...       Build Muscle
# 30  Week 1: Heavy\nExercise Sets Reps\nShoulders\n...       Build Muscle
# 31  High Volume & Intensity\nExercise Sets Reps\nM...       Build Muscle
# 32  Shoulder Workout A (Weeks 1, 3, 5, 7)\nExercis...       Build Muscle
# 33  Exercise Sets Reps Rest\nMilitary Press (AKA O...  Increase Strength
# 34  Exercise Sets Reps Rest\nMilitary Press 5 3 - ...  Increase Strength
# 35  Exercise Sets Reps Rest\nBarbell Bench Press 5...  Increase Strength
# 36  Week Sets/Reps Percentages\nWeek 1 Max Out Wee...  Increase Strength
#
#    Training Level                            Program Duration Days Per Week  \
# 0        Beginner                                     8 Weeks        4 Days
# 1        Beginner                                     6 Weeks        2 Days
# 2    Intermediate                                     8 Weeks        2 Days
# 3        Beginner                                    12 Weeks         3 Day
# 4        Beginner                                     8 Weeks        4 Days
# 5        Beginner                                     4 Weeks        3 Days
# 6        Beginner                                         NaN           NaN
# 7        Beginner                                    12 Weeks        3 Days
# 8    Intermediate                                     8 Weeks         1 Day
# 9    Intermediate                                     8 Weeks         1 Day
# 10       Beginner   8 Weeks\nClick here for the full workout!         4 Day
# 11       Beginner   8 Weeks\nClick here for the full workout!        4 Days
# 12       Beginner                                    12 Weeks        4 Days
# 13       Advanced                                     8 Weeks        5 Days
# 14       Beginner                                     2 Weeks         4 Day
# 15       Beginner                                     8 Weeks        3 Days
# 16       Beginner                                    10 Weeks        4 Days
# 17   Intermediate                                     8 Weeks        3 Days
# 18       Beginner   8 Weeks\nClick here for the full workout!        3 Days
# 19       Beginner                                     4 Weeks         3 Day
# 20       Beginner   8 Weeks\nClick here for the full workout!         4 Day
# 21          Split                                     4 Weeks        3 Days
# 22   Intermediate                                     8 Weeks        1 Days
# 23       Beginner                                     6 Weeks         1 Day
# 24   Intermediate                                     4 Weeks         1 Day
# 25       Beginner                                     8 Weeks         1 Day
# 26   Intermediate                                    10 Weeks        5 Days
# 27       Beginner                                     8 Weeks        3 Days
# 28   Intermediate                                    12 Weeks        5 Days
# 29       Beginner                                    10 Weeks        4 Days
# 30   Intermediate                                     3 Weeks         1 Day
# 31       Advanced                                     6 Weeks         1 Day
# 32   Intermediate                                     8 Weeks         1 Day
# 33       Beginner  10 Weeks\nClick here for the full workout!        3 Days
# 34       Advanced   8 Weeks\nClick here for the full workout!        5 Days
# 35       Beginner  10 Weeks\nClick here for the full workout!         4 Day
# 36       Beginner   8 Weeks\nClick here for the full workout!        5 Days
#
#    Time Per Workout                                          Equipment  \
# 0        45-60 Mins         Barbell, Bodyweight, \nDumbbells, Machines
# 1        45-60 Mins                          Bodyweight,   \nDumbbells
# 2        60-90 Mins            Barbell, Bodyweight,\nCables, Dumbbells
# 3        30-45 Mins  Barbell, Bodyweight, \nCables, Dumbbells, Mach...
# 4      45 - 70 Mins  Bodyweight, Cables, \nDumbbells, EZ Bar, Machines
# 5        15-30 Mins                                         Bodyweight
# 6           15 Mins  Bands, Barbell, \nBodyweight, Foam Roll, Kettl...
# 7        45-60 Mins  Barbell, Bodyweight, \nDumbbells, EZ Bar, Machine
# 8        45-60 Mins            Barbell, Bodyweight,\nCables, Dumbbells
# 9        45-60 Mins             Barbell, Cables, \nDumbbells, Machines
# 10              NaN  Barbell, Bodyweight, Cables, \nDumbbells, Mach...
# 11              NaN  Barbell, Bodyweight, Cables, \nDumbbells, Exer...
# 12       30-45 Mins  Barbell, Bodyweight,\nCables, Dumbbells, Kettl...
# 13       45-60 Mins  Barbell, Bodyweight,\nCables, Dumbbells, EZ Ba...
# 14          60 Mins  Barbell, Bodyweight, \nCables, Dumbbells, Mach...
# 15     45 - 70 Mins          Bodyweight, Cables, \nDumbbells, Machines
# 16     60 - 90 Mins  Bands, Barbell, \nBodyweight, Cables, Dumbbell...
# 17       75-90 Mins           Barbell, Bodyweight, \nCables, Dumbbells
# 18              NaN                                         Bodyweight
# 19       20-45 Mins                                       Kettle Bells
# 20              NaN     Bands, Bodyweight, Dumb -\nbells, Kettle Bells
# 21     30 - 45 Mins                                Barbell, Bodyweight
# 22       45-60 Mins          Bodyweight, Cables, \nDumbbells, Machines
# 23       45-60 Mins                     Barbell, Dumbbells, \nMachines
# 24       45-60 Mins                                  Barbell, Machines
# 25     45 - 60 Mins              Bands, Barbell, \nDumbbells, Machines
# 26     60 - 90 Mins  Barbell, Bodyweight, \nCables, Dumbbells, EZ B...
# 27       25-30 Mins                                          Dumbbells
# 28     45 - 60 Mins                             Bodyweight,\nDumbbells
# 29       45-60 Mins  Barbell, Bodyweight, \nCables, Dumbbells, EZ B...
# 30       30-45 Mins             Barbell, Cables, \nDumbbells, Machines
# 31       45-60 Mins                     Barbell, Dumbbells, \nMachines
# 32       45-75 Mins             Barbell, Cables, \nDumbbells, Machines
# 33              NaN             Barbell, Cables, Dumbbells, \nMachines
# 34              NaN      Barbell, Cables, Dumbbells, \nMachines, Other
# 35              NaN             Barbell, Cables, Dumbbells, \nMachines
# 36              NaN             Barbell, Cables, Dumbbells, \nMachines
#
#                                                Author  \
# 0                                          Steve Shaw
# 1                                    Holly Blumenberg
# 2                                  Coach Dustin Myers
# 3                                      Doug Lawrenson
# 4                                        Josh England
# 5                              Roger “Rock” Lockridge
# 6   Roger “Rock” Lockridge\nFull-Body Focused Warm...
# 7                                       Jonathan Byrd
# 8                              Roger “Rock” Lockridge
# 9                                         Eric Broser
# 10                                                NaN
# 11  Roger “Rock” Lockridge\nWorkout #1 - Upper Bod...
# 12                                          Max Riley
# 13                             Roger “Rock” Lockridge
# 14                                                NaN
# 15                                       Josh England
# 16                                           M&S Team
# 17                                       Josh England
# 18  Roger “Rock” Lockridge\n15-Minute Core Conditi...
# 19                                       Josh England
# 20                                                NaN
# 21                                     Tom MacCormick
# 22                             Team Muscle & Strength
# 23                                   Julie Michaelson
# 24                                         Eric Brown
# 25                             Roger “Rock” Lockridge
# 26                                   Trevor Kouritzin
# 27                                       Josh England
# 28                                       Josh England
# 29                                         Steve Shaw
# 30                             Team Muscle & Strength
# 31                                        Team Allmax
# 32                             Roger “Rock” Lockridge
# 33                                                NaN
# 34                                                NaN
# 35                                                NaN
# 36  Roger “Rock” Lockridge\nMonday - Squat\nTuesda...
#
#                                           Description  Target Gender
# 0   This back and chest specialization workout is ...            NaN
# 1   BACK & SHOULDER WORKOUT ROUTINE \nFOR WOMEN\nT...            NaN
# 2   THE COBRA WORKOUT: \nHEAVY HIGH VOLUME BACK PR...            NaN
# 3   12 WEEK FULL BODY WORKOUT \nROUTINE FOR BEGINN...  Male & Female
# 4   4 DAY UPPER/LOWER PLANET FITNESS\nWORKOUT (MAC...  Male & Female
# 5   BODYWEIGHT BASICS: \n3 DAY BODYWEIGHT WORKOUT ...            NaN
# 6   THE BEST 15-MINUTE WARM-UPS\nMaximize your wor...  Male & Female
# 7   How much do you bench? If you feel it’s never ...            NaN
# 8   BEST CHEST WORKOUT: THE PUSH & \nSTRETCH METHO...            NaN
# 9   PEC-POUNDER: 8 WEEK CHEST WORKOUT \nTO SHATTER...           Male
# 10                  8 WEEK BEGINNER FAT LOSS\nWORKOUT  Male & Female
# 11        8 WEEK BEGINNER FAT LOSS\nWORKOUT FOR WOMEN         Female
# 12  12 WEEK FAT DESTROYER: COMPLETE FAT \nLOSS WOR...            NaN
# 13  SPRING SHRED: 8 WEEK FAT LOSS \nWORKOUT PLAN\n...            NaN
# 14  2-WEEK WORKOUT PLAN TO JUMPSTART \nYOUR RETURN...  Male & Female
# 15  3 DAY FULL BODY\nPLANET FITNESS WORKOUT\nIn th...  Male & Female
# 16  THE BEST FULL BODY WORKOUT\nROUTINE FOR WOMEN\...         Female
# 17  Can’t seem to train for hypertrophy without \n...            NaN
# 18  15-MINUTE CORE CONDITIONING \nWORKOUT YOU CAN ...  Male & Female
# 19  3 DAY FULL BODY BEGINNER \nKETTLEBELL WORKOUT\...  Male & Female
# 20              4-DAY AT-HOME GLUTE\nBUILDING WORKOUT  Male & Female
# 21  BAND ONLY MUSCLE BUILDING\nWORKOUT\nThis effec...  Male & Female
# 22  BOOTY BURNER: COURTNEY KING’S \nFULL GLUTE WOR...            NaN
# 23  Women - who doesn’t want a firm and toned \nbu...            NaN
# 24  This glute focused workout uses the RP-21 \nme...            NaN
# 25  WHEELS WORKOUT: 8 WEEK\nPROGRAM TO BUILD YOUR ...  Male & Female
# 26  5 DAY MUSCLE & STRENGTH BUILDING\nWORKOUT SPLI...           Male
# 27  DUMBBELL ONLY WORKOUT: \n3 DAY FULL BODY DUMBB...            NaN
# 28  DUMBBELL ONLY WORKOUT:\n5 DAY DUMBBELL WORKOUT...  Male & Female
# 29  Reach your muscle building goals with this \nb...            NaN
# 30  Pack on some serious size using a different \n...            NaN
# 31  DELTOID DESTRUCTION: HIGH VOLUME & \nINTENSITY...            NaN
# 32  THE PERFECT WORKOUT FOR ROCK SOLID \nSHOULDERS...  Male & Female
# 33  3 DAY PUSH/PULL/LEGS (PPL)\nWORKOUT FOR BEGINNERS  Male & Female
# 34  BIG AND STRONG: 8 WEEK ADVANCED \nSTRENGTH BUI...  Male & Female
# 35  BOOST YOUR BENCH PRESS: THE ULTIMATE\nWORKOUT ...  Male & Female
# 36  SUPER STRENGTH: 8 WEEK STRENGTH \nBUILDING WOR...  Male & Female

# %% [markdown]
# # Create Queries

# %%
from dotenv import load_dotenv
import os

load_dotenv()

gemini_api_key = os.getenv("GEMINI_API_KEY")

# %%
from langchain_google_genai import ChatGoogleGenerativeAI

MODEL_NAME = "gemini-2.5-flash-preview-05-20"

gemini_chat = ChatGoogleGenerativeAI(model=MODEL_NAME, temperature=0, api_key=gemini_api_key)
gemini_chat_half = ChatGoogleGenerativeAI(model=MODEL_NAME, temperature=0.5, api_key=gemini_api_key)
gemini_chat_1 = ChatGoogleGenerativeAI(model=MODEL_NAME, temperature=1, api_key=gemini_api_key)

# %%
from langchain_core.messages import SystemMessage, HumanMessage

def create_prompt(metadata, model):
    system_message = SystemMessage(
        content=(
            "You are a fitness coach recruiter creating user personas."
        )
    )
    message = (
        "Given this workout plan metadata and description generate a realistic user query "
        "describing their goals, background, and constraints in 2-3 sentences."
        "\n".join(f"- {k}: {v}" for k,v in metadata.items())
    )
    user_message = HumanMessage(
        content=message
    )

    response = model.invoke([system_message, user_message])

    return response.content

# %%
metadata = master_df[["Main Goal", "Training Level", "Program Duration", "Days Per Week", "Time Per Workout", "Equipment", "Target Gender", "Description"]].to_dict(orient='records')

# %%
prompts = []
for m in metadata:
    prompts.append(create_prompt(m, gemini_chat))
    time.sleep(10)

# %%
prompts_half = []
for m in metadata:
    prompts_half.append(create_prompt(m, gemini_chat_half))
    time.sleep(10)

# %%
prompts_1 = []
for m in metadata:
    prompts_1.append(create_prompt(m, gemini_chat_1))
    time.sleep(10)

# %%
query_df = pd.DataFrame({
    'query_0': prompts,
    'query_half': prompts_half,
    'query_1': prompts_1,
})
query_df.to_csv('queries.csv', index=False)

# %%
query_df
# Out:
#                                               query_0  \
# 0   "As a beginner, I'm looking for an 8-week prog...
# 1   "As a beginner woman, I'm looking for a 6-week...
# 2   "I'm an intermediate lifter seeking an 8-week ...
# 3   "I'm a complete beginner looking to build musc...
# 4   "I'm a beginner looking to build muscle over t...
# 5   "I'm a complete beginner looking to improve my...
# 6   "I'm a beginner looking for a quick and effect...
# 7   "As a beginner, I'm looking for a structured 1...
# 8   "I'm an intermediate lifter focused on buildin...
# 9   "As an intermediate male lifter, I'm really fr...
# 10  "I'm a complete beginner looking to finally lo...
# 11  "I'm a beginner female looking for an 8-week w...
# 12  "As a beginner, I'm looking for a structured 1...
# 13  "I'm an advanced lifter who's ready to transit...
# 14  "I'm a beginner looking to get back into gener...
# 15  "I'm a beginner looking to build muscle and ne...
# 16  "As a beginner female, I'm looking for a compr...
# 17  "I'm an intermediate lifter who wants to build...
# 18  "I'm a complete beginner looking to improve my...
# 19  "I'm a complete beginner looking to build musc...
# 20  "I'm a beginner looking for an effective 8-wee...
# 21  "I'm looking for a 4-week muscle-building prog...
# 22  "I'm an intermediate lifter aiming to build an...
# 23  "As a beginner woman, I'm looking for a focuse...
# 24  "As an intermediate lifter, I'm looking for an...
# 25  "I'm a beginner who really wants to build some...
# 26  "As an intermediate male lifter, I'm seeking a...
# 27  "I'm a complete beginner who wants to start bu...
# 28  "As an intermediate lifter, I'm looking for a ...
# 29  I'm a beginner looking for a structured 10-wee...
# 30  "As an intermediate lifter, I'm looking for an...
# 31  "As an advanced lifter, I need an intense, hig...
# 32  "I'm an intermediate lifter looking for an eff...
# 33  "I'm a complete beginner looking to significan...
# 34  "As an advanced lifter, I'm seeking an intensi...
# 35  "I'm a beginner looking for a structured 10-we...
# 36  "As a complete beginner, I'm looking for an 8-...
#
#                                            query_half  \
# 0   "I'm a beginner looking for an 8-week program ...
# 1   "As a beginner woman, I'm looking for a 6-week...
# 2   "I'm an intermediate lifter focused on buildin...
# 3   "I'm a complete beginner aiming to build muscl...
# 4   "As a beginner, I'm looking for an 8-week prog...
# 5   "I'm a complete beginner looking to improve my...
# 6   "I'm a beginner looking for quick and effectiv...
# 7   I'm a beginner lifter who feels my bench press...
# 8   "As an intermediate lifter, I'm aiming to buil...
# 9   "I'm an intermediate male lifter who's hit a p...
# 10  "I'm a complete beginner looking for a structu...
# 11  "I'm a beginner woman looking for an effective...
# 12  "As a beginner, my primary goal is to get ripp...
# 13  "I'm an advanced lifter seeking an intensive 8...
# 14  "I'm a beginner looking for a short, effective...
# 15  "I'm a beginner looking to build muscle over t...
# 16  As a beginner female, my main goal is to lose ...
# 17  "As an intermediate lifter, I'm seeking an 8-w...
# 18  "I'm a complete beginner looking to improve my...
# 19  "I'm a complete beginner looking to build some...
# 20  "As a complete beginner, I'm looking for an 8-...
# 21  "I'm a busy individual looking for an effectiv...
# 22  "I'm an intermediate lifter looking for an 8-w...
# 23  "I'm a beginner woman eager to build muscle an...
# 24  "I'm an intermediate lifter focused on buildin...
# 25  "I'm a complete beginner looking to build stro...
# 26  I'm an intermediate male lifter aiming to sign...
# 27  "I'm a complete beginner looking to build musc...
# 28  "I'm an intermediate lifter aiming to build si...
# 29  "I'm a beginner looking for a structured 10-we...
# 30  As an intermediate lifter, I'm looking to pack...
# 31  "I'm an advanced lifter with a strong foundati...
# 32  "I'm an intermediate lifter aiming to build si...
# 33  "I'm a complete beginner to strength training ...
# 34  "I'm an advanced lifter seeking an intensive 8...
# 35  "As a complete beginner, I'm really motivated ...
# 36  "I'm a complete beginner who wants to signific...
#
#                                               query_1
# 0   "As a beginner, I'm looking for an 8-week prog...
# 1   I'm a beginner woman looking to build muscle, ...
# 2   "I'm an intermediate lifter seeking an 8-week ...
# 3   "I'm a complete beginner looking to build musc...
# 4   "I'm a beginner looking to build muscle over t...
# 5   "I'm a complete beginner looking to establish ...
# 6   "I'm a fitness beginner looking to improve my ...
# 7   "I'm a beginner looking for a focused program ...
# 8   "I'm an intermediate lifter focused on buildin...
# 9   "As an intermediate male lifter, I'm really fr...
# 10  "I'm a complete beginner who wants to lose fat...
# 11  "As a beginner woman, my main goal is to lose ...
# 12  "As a beginner, my main goal is to get ripped ...
# 13  "I'm an advanced lifter ready to commit to an ...
# 14  "I'm looking for a beginner-friendly gym worko...
# 15  "I'm a beginner looking to build muscle and ne...
# 16  "As a beginner female, I'm looking for a compr...
# 17  "As an intermediate lifter, I'm looking for an...
# 18  "As a beginner, I'm looking for a simple 8-wee...
# 19  "I'm a complete beginner looking to start buil...
# 20  "I'm a complete beginner aiming to build muscl...
# 21  "I'm looking for an efficient, 4-week program ...
# 22  "I'm an intermediate exerciser looking for an ...
# 23  "I'm a beginner looking to build muscle and ac...
# 24  "I'm an intermediate lifter looking for an eff...
# 25  "I'm a complete beginner looking to seriously ...
# 26  "As an intermediate male lifter, I'm looking f...
# 27  I'm a complete beginner looking for an effecti...
# 28  "As an intermediate lifter, I'm looking for a ...
# 29  "I'm a beginner looking to seriously build mus...
# 30  "I'm an intermediate lifter with limited gym t...
# 31  As an advanced lifter, I'm looking for a high-...
# 32  "As an intermediate lifter, I'm really looking...
# 33  "I'm a complete beginner looking for a structu...
# 34  "I'm an advanced lifter seeking a challenging ...
# 35  "As a beginner lifter, I'm eager to significan...
# 36  "I'm a complete beginner eager to build founda...

# %% [markdown]
# # LLM as a Judge

# %%
query_df = pd.read_csv('queries.csv')

# %%
from pydantic import BaseModel, Field
from typing import Literal

class PlanComparison(BaseModel):
    relevance: Literal["A", "B", "Tie"] = Field(
        description="Which plan better aligns with the persona's stated goals"
    )
    completeness: Literal["A", "B", "Tie"] = Field(
        description="Which plan provides more thorough information"
    )
    creativity: Literal["A", "B", "Tie"] = Field(
        description="Which plan shows more novel or varied exercise choices"
    )
    safety_and_evidence: Literal["A", "B", "Tie"] = Field(
        description="Which plan is safer and more grounded in exercise science"
    )
    clarity: Literal["A", "B", "Tie"] = Field(
        description="Which plan is more clearly written and well-organized"
    )
    overall: Literal["A", "B", "Tie"] = Field(
        description="Overall better plan considering all criteria"
    )
    rationale: str = Field(
        description="A brief, objective explanation of the judgment"
    )

# %%
from langchain_core.messages import SystemMessage, HumanMessage

structured_model = gemini_chat.with_structured_output(PlanComparison)

def judge(query, baseline_plan, agent_plan):
    system_message = SystemMessage(
        content=(
            "You are an expert fitness coach."
        )
    )
    message = f"""Given the User Persona:
{query}

Plan A:
{baseline_plan}

Plan B:
{agent_plan}

Evaluate each plan on five dimensions: Relevance, Completeness, Creativity, Safety and Evidence-Grounding, and Clarity and Organization. without bias toward presentation order, response length, or plan names.

For each dimension, choose “A” if Plan A is stronger, “B” if Plan B is stronger, or “Tie” if they are equal. Then decide the overall winner in the same way. Finally, provide a concise rationale.

Output must conform to the PlanComparison schema."""
    user_message = HumanMessage(
        content=message
    )

    response = structured_model.invoke([system_message, user_message])

    return response

# %%
# import agent

for col in query_df.columns:
    plans = []
    judges = []
    for i in range(len(query_df)):
        agent_plan = agent.invoke("query": query_df[col][i])
        time.sleep(10)
        plans.append(agent_plan)
        judges.append(judge(query_df[col][i], master_df['tables'][i], agent_plan))
        time.sleep(10)
    query_df[f'plan_{col}'] = plans
    query_df[f'judge_{col}'] = judges

# %% [markdown]
# # Analysis

# %%
from sklearn.metrics import cohen_kappa_score

df = pd.DataFrame(judges)

overall_counts = df.query("overall in ['A','B']")['overall'].value_counts()
n_overall = overall_counts.sum()
win_rate_A = overall_counts.get('A', 0) / n_overall
win_rate_B = overall_counts.get('B', 0) / n_overall

print(f"Overall win-rate: Baseline = {win_rate_A:.2%}, Agent = {win_rate_B:.2%} (n={n_overall})")

criteria = ['relevance', 'completeness', 'creativity', 'safety_and_evidence', 'clarity']
breakdown = {}
for crit in criteria:
    print(f"\n--- {crit.capitalize()} Breakdown ---")

    cnts = df.query(f"{crit} in ['A','B']")[crit].value_counts()
    a = cnts.get('A', 0)
    b = cnts.get('B', 0)
    print(f"{crit.capitalize()}: Baseline = {a}, Agent = {b}, tie/skipped = {len(df) - (a+b)}")

    kappa_rel = cohen_kappa_score(
        df['overall'].replace('Tie', pd.NA).dropna(),
        df[crit].replace('Tie', pd.NA).dropna()
    )
    print(f"Cohen's Kappa (overall vs {crit}): {kappa_rel:.2f}")
    
    breakdown[crit] = {'A_wins': a, 'B_wins': b, 'kappa': kappa_rel}
# Out:
# Overall win-rate: Baseline = 50.00%, Agent = 50.00% (n=2)
#
# --- Relevance Breakdown ---
# Relevance: Baseline = 1, Agent = 1, tie/skipped = 0
# Cohen's Kappa (overall vs relevance): 1.00
#
# --- Completeness Breakdown ---
# Completeness: Baseline = 1, Agent = 1, tie/skipped = 0
# Cohen's Kappa (overall vs completeness): -1.00
#
# --- Creativity Breakdown ---
# Creativity: Baseline = 1, Agent = 1, tie/skipped = 0
# Cohen's Kappa (overall vs creativity): 1.00
#
# --- Safety_and_evidence Breakdown ---
# Safety_and_evidence: Baseline = 1, Agent = 1, tie/skipped = 0
# Cohen's Kappa (overall vs safety_and_evidence): -1.00
#
# --- Clarity Breakdown ---
# Clarity: Baseline = 1, Agent = 1, tie/skipped = 0
# Cohen's Kappa (overall vs clarity): 1.00
